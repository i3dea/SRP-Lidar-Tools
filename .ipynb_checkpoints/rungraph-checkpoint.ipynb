# %%
# %pylab inline
# !conda env export
# Out:
# Populating the interactive namespace from numpy and matplotlib
# name: C:\Anaconda\envs\srp
# dependencies:
# - affine=1.2.0=py27_0
# - backports_abc=0.4=py27_0
# - bzip2=1.0.6=vc9_2
# - click=6.3=py27_0
# - cligj=0.2.0=py27_0
# - curl=7.45.0=vc9_1
# - cycler=0.10.0=py27_0
# - decorator=4.0.9=py27_0
# - docopt=0.6.2=py27_0
# - enum34=1.1.2=py27_0
# - fiona=1.6.0=np110py27_0
# - freetype=2.5.5=vc9_0
# - futures=3.0.3=py27_0
# - gdal=2.0.0=py27_1
# - geos=3.4.2=vc9_0
# - hdf4=4.2.11=0
# - hdf5=1.8.15.1=vc9_4
# - ipykernel=4.3.1=py27_0
# - ipyparallel=5.0.1=py27_0
# - ipython=4.1.2=py27_0
# - ipython-notebook=4.0.4=py27_3
# - ipython_genutils=0.1.0=py27_0
# - ipywidgets=4.1.1=py27_0
# - jinja2=2.8=py27_0
# - jpeg=8d=vc9_0
# - jsonschema=2.4.0=py27_0
# - jupyter=1.0.0=py27_1
# - jupyter_client=4.2.1=py27_0
# - jupyter_console=4.1.1=py27_0
# - jupyter_core=4.1.0=py27_0
# - kealib=1.4.5=vc9_0
# - libgdal=2.0.0=vc9_2
# - libnetcdf=4.3.3.1=vc9_5
# - libpng=1.6.17=vc9_1
# - libspatialindex=1.8.5=1
# - libtiff=4.0.6=vc9_1
# - markupsafe=0.23=py27_0
# - matplotlib=1.5.1=np110py27_0
# - mistune=0.7.1=py27_0
# - mkl=11.3.1=0
# - msvc_runtime=1.0.1=vc9_0
# - nbconvert=4.1.0=py27_0
# - nbformat=4.0.1=py27_0
# - networkx=1.11=py27_0
# - notebook=4.1.0=py27_0
# - numpy=1.10.4=py27_0
# - openssl=1.0.2d=vc9_0
# - pandas=0.17.1=np110py27_0
# - path.py=8.1.2=py27_1
# - pickleshare=0.5=py27_0
# - pillow=3.1.1=py27_0
# - pip=8.1.0=py27_0
# - progressbar=2.3=py27_0
# - proj4=4.9.1=vc9_0
# - pygments=2.1.1=py27_0
# - pyparsing=2.0.3=py27_0
# - pyqt=4.11.4=py27_5
# - pyreadline=2.1=py27_0
# - python=2.7.11=2
# - python-dateutil=2.4.2=py27_0
# - pytz=2015.7=py27_0
# - pywget=2.2=py27_0
# - pyyaml=3.11=py27_2
# - pyzmq=15.2.0=py27_0
# - qt=4.8.7=vc9_6
# - qtconsole=4.1.1=py27_0
# - rasterio=0.25.0=np110py27_0
# - rtree=0.8.2=py27_2
# - scikit-image=0.11.3=np110py27_0
# - scikit-learn=0.17.1=np110py27_0
# - scipy=0.17.0=np110py27_0
# - setuptools=20.2.2=py27_0
# - simplegeneric=0.8.1=py27_0
# - singledispatch=3.4.0.3=py27_0
# - sip=4.16.9=py27_2
# - six=1.10.0=py27_0
# - snuggs=1.3.1=np110py27_0
# - ssl_match_hostname=3.4.0.2=py27_0
# - tk=8.5.18=vc9_0
# - tornado=4.3=py27_0
# - traitlets=4.1.0=py27_0
# - wheel=0.29.0=py27_0
# - xerces-c=3.1.2=vc9_0
# - zlib=1.2.8=vc9_2
# - pip:
#   - backports-abc==0.4
#   - backports.ssl-match-hostname==3.4.0.2
#   - beautifulsoup4==4.4.1
#   - bunch==1.0.1
#   - cartopy==0.13.1
#   - cython==0.23.4
#   - ipython-genutils==0.1.0
#   - jupyter-client==4.2.1
#   - jupyter-console==4.1.1
#   - jupyter-core==4.1.0
#   - laspy==1.4.1
#   - liblas==1.8.0
#   - pyepsg==0.1.0
#   - pylas==0.1.2
#   - pyprind==2.9.3
#   - pyshp==1.2.3
#   - requests==2.8.1
#   - robobrowser==0.5.3
#   - shapely==1.5.13
#   - werkzeug==0.11.2
#   - wget==2.2

# %%
import pandas as pd
from pandas import DataFrame

# %%
rawdata = pd.read_csv('rungraph.txt', sep='\t')

# %%
rawdata[:5]
# Out:
#    ObjId  PtId           x          y      z
# 0     58     0 -111.925523  33.480422  382.3
# 1     58     1 -111.925556  33.480422  382.3
# 2     58     2 -111.925588  33.480422  382.3
# 3     58     3 -111.925620  33.480423  382.3
# 4     58     4 -111.925654  33.480423  382.3

# %%
import cartopy
import cartopy.io.img_tiles
import cartopy.crs

# %%
figsize(15, 15)
tiler = cartopy.io.img_tiles.GoogleTiles()
epsg2223 = cartopy.crs.epsg(2223) # State Plane AZ Central (ft)
ax = plt.axes(projection=tiler.crs)
ax.add_image(tiler, 17)
ax.scatter(rawdata['x'], 
           rawdata['y'],
           s=0.1,
           zorder=5,
           transform=epsg2223.as_geodetic())

show()

# %%
xmin, xmax = rawdata['x'].min(), rawdata['x'].max()
ymin, ymax = rawdata['y'].min(), rawdata['y'].max()
print xmin, xmax, ymin, ymax
# Out:
# -111.943614549 -111.925522849 33.4655532957 33.480701779

# %%
xyz = epsg2223.transform_points(epsg2223.as_geodetic(), 
                                np.asarray(rawdata['x']), 
                                np.asarray(rawdata['y']),
                                np.asarray(rawdata['z']),
                               )

# %%
xmin, ymin, zmin = xyz.min(0)
xmax, ymax, zmax = xyz.max(0)
print 'x(ft):', xmin, '--', xmax
print 'y(ft):', ymin, '--', ymax
print 'width(ft):', xmax-xmin
print 'height(ft):', ymax-ymin
# Out:
# x(ft): 691782.186442 -- 697299.731378
# y(ft): 896917.559782 -- 902428.749975
# width(ft): 5517.54493594
# height(ft): 5511.19019279

# %% [markdown]
# the units of epsg2223 should be feet.  The study area appears to be about one square mile.

# %% [markdown]
# The resolution of the data seemt to be much higher than feet. We shold probably rasterize into 6inch bins (or less)

# %%
import rasterio
import liblas
import pyepsg
proj4_2223 = pyepsg.get(2223).as_proj4()

# %%
import os
meters_to_inches = 39.3701
from ipywidgets import FloatProgress
from IPython.display import display, clear_output

# %% [markdown]
# # Now we will render out the LiDAR data
# Do not execute the next cells if you already have rgbz0_inches.tif

# %%
folder = r'G:\SRP Scan data\AZ_SRP_Section34_Seiler\Export\Section34_LAS12_AZC_m'
files = [f for f in os.listdir(folder) if f.endswith('.las')]

print len(files), "LiDAR files"
print int(round(5.5*60*60/len(files))), "seconds per file on avg"
# Out:
# 515 LiDAR files
# 38 seconds per file on avg

# %% [markdown]
# I have converted the next cell in this notebook to "raw" format, so that I do not accidentally execute it if I try to run every cell in the notebook. The next cell takes about 5 hours and 30 minutes to complete since it goes through all 515 LiDAR files. That is not so bad since it was around 38 seconds per lidar file.

# %%
# The size of the image -- I think we can fit the whole study area into one big tile
ft_per_pixel = 1.0/12.0  
width=5000
height=5000

# %%
xmax = xmin + width*ft_per_pixel
ymax = ymin + height*ft_per_pixel

# %%
import time
import laspy

affine = rasterio.transform.from_bounds(xmin, ymin, xmax, ymax, width, height)
ras = np.ones((height, width, 4), dtype=float)*0xFFFFFFFF

poverall = FloatProgress(min=0, max=len(files))
p = FloatProgress(min=0, max=1)

display(poverall)
display(p)

epsg2223 = cartopy.crs.epsg(2223) # State Plane AZ Central (ft)
epsg26949 = cartopy.crs.epsg(26949) # State Plane AZ Central (m)


tstart = time.clock()

for file_index, basefn in enumerate(files):
    
    # Progress display so I know how long I have to get coffee
    poverall.value = file_index
    p.value = 0
    
    seconds = ((time.clock()-tstart)/max(file_index,1))*(len(files)-file_index)
    minutes, seconds = divmod(seconds, 60)
    hours, minutes = divmod(minutes, 60)
    print "ETA:  %d:%02d:%02d" % (hours,  minutes, seconds)
    
    print basefn
    fn = os.path.join(folder, basefn)
    f = laspy.file.File(fn)
    
    fxmin, fymin = epsg2223.transform_point(f.header.min[0], f.header.min[1], epsg26949)
    fxmax, fymax = epsg2223.transform_point(f.header.max[0], f.header.max[1], epsg26949)
    
    if fxmax < xmin: continue
    if fxmin > xmax: continue
    if fymax < ymin: continue
    if fymin > ymax: continue
        
    x = f.x
    y = f.y
    z = f.z
    r = f.red
    g = f.green
    b = f.blue
    xyzf = epsg2223.transform_points(epsg26949, x, y, z)
    xyzf[:, 2] *= 12 #inches
    rc = np.column_stack(~affine*xyzf[:,:2].T).astype(int)

    print "\rSorting",
    indices = np.argsort(xyzf[:, 2] )
    valid_indices = ((rc[indices, 1] < width) 
                     & (rc[indices, 1] > 0) 
                     & (rc[indices, 0] < height)
                     & (rc[indices, 0] > 0))
    indices = indices[valid_indices]
    indices = indices[::-1]

    tmp = np.ones_like(ras)*0xFFFFFFFF
    chunksize  = 1000
    n = len(indices)
    print '\r', n,
    p.max = n
    for start in range(0, n, chunksize):
        end = min(start + chunksize, n)
        ix = indices[start:end]
        tmp[rc[ix, 0], rc[ix, 1], 0] = r[ix]
        tmp[rc[ix, 0], rc[ix, 1], 1] = g[ix]
        tmp[rc[ix, 0], rc[ix, 1], 2] = b[ix]
        tmp[rc[ix, 0], rc[ix, 1], 3] = xyzf[ix, 2]
        p.value = start
        print '\r{:>10} / {}'.format(end, n), 
    
    updates = tmp[:,:,3] < ras[:,:,3]
    ras[updates] = tmp[updates]
# Out:
#  ETA:  0:00:01
# Lt._20130817(0)_LAS1_2.las
# ETA:  0:00:03
# Lt._20130817(1)_LAS1_2.las
#    1066409 / 1066409 ETA:  0:53:57
# Lt._20130817(10)_LAS1_2.las
# ETA:  0:35:54
# Lt._20130817(100)_LAS1_2.las
# ETA:  0:26:53
# Lt._20130817(101)_LAS1_2.las
# ETA:  0:21:28
# Lt._20130818(139)_LAS1_2.las
# ETA:  0:12:23
# Lt._20130818(140)_LAS1_2.las
# ETA:  0:12:16
# Lt._20130818(141)_LAS1_2.las
# ETA:  0:12:09
# Lt._20130818(142)_LAS1_2.las
# ETA:  0:12:03
# Lt._20130818(143)_LAS1_2.las
# ETA:  0:11:56
# Lt._20130818(144)_LAS1_2.las
# ETA:  0:11:49
# Lt._20130818(145)_LAS1_2.las
# ETA:  0:11:42
# Lt._20130818(146)_LAS1_2.las
# ETA:  0:11:36
# Lt._20130818(147)_LAS1_2.las
# ETA:  0:11:29
# Lt._20130818(148)_LAS1_2.las
# ETA:  0:11:23
# Lt._20130818(149)_LAS1_2.las
# ETA:  0:11:17
# Lt._20130818(150)_LAS1_2.las
# ETA:  0:11:10
# Lt._20130818(151)_LAS1_2.las
# ETA:  0:11:04
# Lt._20130818(152)_LAS1_2.las
# ETA:  0:10:58
# Lt._20130818(153)_LAS1_2.las
# ETA:  0:10:52
# Lt._20130818(154)_LAS1_2.las
# ETA:  0:10:46
# Lt._20130818(155)_LAS1_2.las
# ETA:  0:10:41
# Lt._20130818(156)_LAS1_2.las
# ETA:  0:10:35
# Lt._20130818(157)_LAS1_2.las
# ETA:  0:10:29
# Lt._20130818(158)_LAS1_2.las
# ETA:  0:10:24
# Lt._20130818(159)_LAS1_2.las
# ETA:  0:10:18
# Lt._20130818(160)_LAS1_2.las
# ETA:  0:10:13
# Lt._20130818(161)_LAS1_2.las
# ETA:  0:10:07
# Lt._20130818(162)_LAS1_2.las
# ETA:  0:10:02
# Lt._20130818(163)_LAS1_2.las
# ETA:  0:09:57
# Lt._20130818(164)_LAS1_2.las
# ETA:  0:09:51
# Lt._20130818(165)_LAS1_2.las
# ETA:  0:09:46
# Lt._20130818(166)_LAS1_2.las
# ETA:  0:09:41
# Lt._20130818(167)_LAS1_2.las
# ETA:  0:09:36
# Lt._20130818(168)_LAS1_2.las
# ETA:  0:09:31
# Lt._20130818(169)_LAS1_2.las
# ETA:  0:09:26
# Lt._20130818(170)_LAS1_2.las
# ETA:  0:09:21
# Lt._20130818(171)_LAS1_2.las
# ETA:  0:09:16
# Lt._20130818(172)_LAS1_2.las
# ETA:  0:09:12
# Lt._20130818(173)_LAS1_2.las
# ETA:  0:09:07
# Lt._20130818(174)_LAS1_2.las
# ETA:  0:09:02
# Lt._20130818(175)_LAS1_2.las
# ETA:  0:08:58
# Lt._20130818(176)_LAS1_2.las
# ETA:  0:08:53
# Lt._20130818(177)_LAS1_2.las
# ETA:  0:08:49
# Lt._20130818(178)_LAS1_2.las
# ETA:  0:08:44
# Lt._20130818(179)_LAS1_2.las
# ETA:  0:08:40
# Lt._20130818(180)_LAS1_2.las
# ETA:  0:08:35
# Lt._20130818(181)_LAS1_2.las
# ETA:  0:08:31
# Lt._20130818(182)_LAS1_2.las
# ETA:  0:08:27
# Lt._20130818(183)_LAS1_2.las
# ETA:  0:08:23
# Lt._20130818(184)_LAS1_2.las
# ETA:  0:08:18
# Lt._20130818(185)_LAS1_2.las
# ETA:  0:08:14
# Lt._20130818(186)_LAS1_2.las
# ETA:  0:08:10
# Lt._20130818(187)_LAS1_2.las
# ETA:  0:08:06
# Lt._20130818(188)_LAS1_2.las
# ETA:  0:08:02
# Lt._20130818(189)_LAS1_2.las
# ETA:  0:07:58
# Lt._20130818(190)_LAS1_2.las
# ETA:  0:07:54
# Lt._20130818(191)_LAS1_2.las
# ETA:  0:07:50
# Lt._20130818(192)_LAS1_2.las
# ETA:  0:07:47
# Lt._20130818(193)_LAS1_2.las
# ETA:  0:07:43
# Lt._20130818(194)_LAS1_2.las
# ETA:  0:07:39
# Lt._20130818(195)_LAS1_2.las
# ETA:  0:07:35
# Lt._20130818(196)_LAS1_2.las
# ETA:  0:07:32
# Lt._20130818(197)_LAS1_2.las
# ETA:  0:07:28
# Lt._20130818(198)_LAS1_2.las
# ETA:  0:07:24
# Lt._20130818(199)_LAS1_2.las
# ETA:  0:07:21
# Lt._20130818(200)_LAS1_2.las
# ETA:  0:07:19
# Lt._20130818(201)_LAS1_2.las
# ETA:  0:07:16
# Lt._20130818(202)_LAS1_2.las
# ETA:  0:07:12
# Lt._20130818(203)_LAS1_2.las
# ETA:  0:07:09
# Lt._20130818(204)_LAS1_2.las
# ETA:  0:07:06
# Lt._20130818(205)_LAS1_2.las
# ETA:  0:07:02
# Lt._20130818(206)_LAS1_2.las
# ETA:  0:06:59
# Lt._20130818(207)_LAS1_2.las
# ETA:  0:06:55
# Lt._20130818(208)_LAS1_2.las
# ETA:  0:06:52
# Lt._20130818(209)_LAS1_2.las
# ETA:  0:06:49
# Lt._20130818(210)_LAS1_2.las
# ETA:  0:06:46
# Lt._20130818(211)_LAS1_2.las
# ETA:  0:06:42
# Lt._20130818(212)_LAS1_2.las
# ETA:  0:06:39
# Lt._20130818(213)_LAS1_2.las
# ETA:  0:06:36
# Lt._20130818(214)_LAS1_2.las
# ETA:  0:06:33
# Lt._20130818(215)_LAS1_2.las
# ETA:  0:06:30
# Lt._20130818(216)_LAS1_2.las
# ETA:  0:06:27
# Lt._20130818(217)_LAS1_2.las
# ETA:  0:06:24
# Lt._20130818(218)_LAS1_2.las
# ETA:  0:06:21
# Lt._20130818(219)_LAS1_2.las
# ETA:  0:06:18
# Lt._20130818(220)_LAS1_2.las
# ETA:  0:06:15
# Lt._20130818(221)_LAS1_2.las
# ETA:  0:06:12
# Lt._20130818(222)_LAS1_2.las
# ETA:  0:06:09
# Lt._20130818(223)_LAS1_2.las
# ETA:  0:06:06
# Lt._20130818(224)_LAS1_2.las
# ETA:  0:06:03
# Lt._20130818(225)_LAS1_2.las
# ETA:  0:06:00
# Lt._20130818(226)_LAS1_2.las
# ETA:  0:05:57
# Lt._20130818(227)_LAS1_2.las
# ETA:  0:05:55
# Lt._20130818(228)_LAS1_2.las
# ETA:  0:05:52
# Lt._20130818(229)_LAS1_2.las
# ETA:  0:05:49
# Lt._20130818(230)_LAS1_2.las
# ETA:  0:05:47
# Lt._20130818(231)_LAS1_2.las
# ETA:  0:05:44
# Lt._20130818(232)_LAS1_2.las
# Rt._20130817(46)_LAS1_2.las
# ETA:  0:04:59
# Rt._20130817(47)_LAS1_2.las
# ETA:  0:04:57
# Rt._20130817(48)_LAS1_2.las
# ETA:  0:04:54
# Rt._20130817(49)_LAS1_2.las
# ETA:  0:04:52
# Rt._20130817(5)_LAS1_2.las
#    2308719 / 2308719 ETA:  0:05:09
# Rt._20130817(50)_LAS1_2.las
#          5 / 5 ETA:  0:05:19
# Rt._20130817(51)_LAS1_2.las
#          5 / 5 ETA:  0:05:29
# Rt._20130817(52)_LAS1_2.las
#        184 / 184 ETA:  0:05:30
# Rt._20130817(53)_LAS1_2.las
# ETA:  0:05:27
# Rt._20130817(54)_LAS1_2.las
# ETA:  0:05:24
# Rt._20130817(55)_LAS1_2.las
# ETA:  0:05:21
# Rt._20130817(56)_LAS1_2.las
# ETA:  0:05:18
# Rt._20130817(57)_LAS1_2.las
# ETA:  0:05:16
# Rt._20130817(58)_LAS1_2.las
# ETA:  0:05:13
# Rt._20130817(59)_LAS1_2.las
# ETA:  0:05:10
# Rt._20130817(6)_LAS1_2.las
#    1266919 / 1266919 ETA:  0:05:23
# Rt._20130817(60)_LAS1_2.las
# ETA:  0:05:21
# Rt._20130817(61)_LAS1_2.las
# ETA:  0:05:18
# Rt._20130817(62)_LAS1_2.las
# ETA:  0:05:15
# Rt._20130817(63)_LAS1_2.las
# ETA:  0:05:12
# Rt._20130817(64)_LAS1_2.las
#          3 / 3 ETA:  0:05:13
# Rt._20130817(65)_LAS1_2.las
# ETA:  0:05:10
# Rt._20130817(66)_LAS1_2.las
# ETA:  0:05:07
# Rt._20130817(67)_LAS1_2.las
# ETA:  0:05:05
# Rt._20130817(68)_LAS1_2.las
# ETA:  0:05:02
# Rt._20130817(69)_LAS1_2.las
# ETA:  0:04:59
# Rt._20130817(7)_LAS1_2.las
# ETA:  0:04:56
# Rt._20130817(70)_LAS1_2.las
# ETA:  0:04:54
# Rt._20130817(71)_LAS1_2.las
# ETA:  0:04:51
# Rt._20130817(72)_LAS1_2.las
# ETA:  0:04:48
# Rt._20130817(73)_LAS1_2.las
# ETA:  0:04:46
# Rt._20130817(74)_LAS1_2.las
# ETA:  0:04:43
# Rt._20130817(75)_LAS1_2.las
# ETA:  0:04:40
# Rt._20130817(76)_LAS1_2.las
# ETA:  0:04:38
# Rt._20130817(77)_LAS1_2.las
# ETA:  0:04:35
# Rt._20130817(78)_LAS1_2.las
# ETA:  0:04:33
# Rt._20130817(79)_LAS1_2.las
# ETA:  0:04:30
# Rt._20130817(8)_LAS1_2.las
# ETA:  0:04:28
# Rt._20130817(80)_LAS1_2.las
# ETA:  0:04:25
# Rt._20130817(81)_LAS1_2.las
# ETA:  0:04:23
# Rt._20130817(82)_LAS1_2.las
# ETA:  0:04:20
# Rt._20130817(83)_LAS1_2.las
# ETA:  0:04:18
# Rt._20130817(84)_LAS1_2.las
# ETA:  0:04:15
# Rt._20130817(85)_LAS1_2.las
# ETA:  0:04:13
# Rt._20130817(86)_LAS1_2.las
# ETA:  0:04:10
# Rt._20130817(87)_LAS1_2.las
# ETA:  0:04:08
# Rt._20130817(88)_LAS1_2.las
# ETA:  0:04:05
# Rt._20130817(89)_LAS1_2.las
# ETA:  0:04:03
# Rt._20130817(9)_LAS1_2.las
# ETA:  0:04:00
# Rt._20130817(90)_LAS1_2.las
# ETA:  0:03:58
# Rt._20130817(91)_LAS1_2.las
# ETA:  0:03:56
# Rt._20130817(92)_LAS1_2.las
# ETA:  0:03:53
# Rt._20130817(93)_LAS1_2.las
# ETA:  0:03:51
# Rt._20130817(94)_LAS1_2.las
# ETA:  0:03:49
# Rt._20130817(95)_LAS1_2.las
# ETA:  0:03:46
# Rt._20130817(96)_LAS1_2.las
# ETA:  0:03:44
# Rt._20130817(97)_LAS1_2.las
# ETA:  0:03:42
# Rt._20130817(98)_LAS1_2.las
# ETA:  0:03:39
# Rt._20130817(99)_LAS1_2.las
# ETA:  0:03:37
# Rt._20130818(127)_LAS1_2.las
# ETA:  0:03:35
# Rt._20130818(128)_LAS1_2.las
# ETA:  0:03:33
# Rt._20130818(129)_LAS1_2.las
# ETA:  0:03:30
# Rt._20130818(130)_LAS1_2.las
# ETA:  0:03:28
# Rt._20130818(131)_LAS1_2.las
# ETA:  0:03:26
# Rt._20130818(132)_LAS1_2.las
# ETA:  0:03:24
# Rt._20130818(133)_LAS1_2.las
# ETA:  0:03:22
# Rt._20130818(134)_LAS1_2.las
# ETA:  0:03:19
# Rt._20130818(135)_LAS1_2.las
# ETA:  0:03:17
# Rt._20130818(136)_LAS1_2.las
# ETA:  0:03:15
# Rt._20130818(137)_LAS1_2.las
# ETA:  0:03:13
# Rt._20130818(138)_LAS1_2.las
# ETA:  0:03:11
# Rt._20130818(139)_LAS1_2.las
# ETA:  0:03:09
# Rt._20130818(140)_LAS1_2.las
# ETA:  0:03:06
# Rt._20130818(141)_LAS1_2.las
# ETA:  0:03:04
# Rt._20130818(142)_LAS1_2.las
# ETA:  0:03:02
# Rt._20130818(143)_LAS1_2.las
# ETA:  0:03:00
# Rt._20130818(144)_LAS1_2.las
# ETA:  0:02:58
# Rt._20130818(145)_LAS1_2.las
# ETA:  0:02:56
# Rt._20130818(146)_LAS1_2.las
# ETA:  0:02:54
# Rt._20130818(147)_LAS1_2.las
# ETA:  0:02:52
# Rt._20130818(148)_LAS1_2.las
# ETA:  0:02:50
# Rt._20130818(149)_LAS1_2.las
# ETA:  0:02:48
# Rt._20130818(150)_LAS1_2.las
# ETA:  0:02:46
# Rt._20130818(151)_LAS1_2.las
# ETA:  0:02:44
# Rt._20130818(152)_LAS1_2.las
# ETA:  0:02:42
# Rt._20130818(153)_LAS1_2.las
# ETA:  0:02:40
# Rt._20130818(154)_LAS1_2.las
# ETA:  0:02:38
# Rt._20130818(155)_LAS1_2.las
# ETA:  0:02:36
# Rt._20130818(156)_LAS1_2.las
# ETA:  0:02:34
# Rt._20130818(157)_LAS1_2.las
# ETA:  0:02:32
# Rt._20130818(158)_LAS1_2.las
# ETA:  0:02:30
# Rt._20130818(159)_LAS1_2.las
# ETA:  0:02:28
# Rt._20130818(160)_LAS1_2.las
# ETA:  0:02:26
# Rt._20130818(161)_LAS1_2.las
# ETA:  0:02:24
# Rt._20130818(162)_LAS1_2.las
# ETA:  0:02:22
# Rt._20130818(163)_LAS1_2.las
# ETA:  0:02:20
# Rt._20130818(164)_LAS1_2.las
# ETA:  0:02:19
# Rt._20130818(165)_LAS1_2.las
# ETA:  0:02:17
# Rt._20130818(166)_LAS1_2.las
# ETA:  0:02:15
# Rt._20130818(167)_LAS1_2.las
# ETA:  0:02:13
# Rt._20130818(168)_LAS1_2.las
# ETA:  0:02:11
# Rt._20130818(169)_LAS1_2.las
# ETA:  0:02:09
# Rt._20130818(170)_LAS1_2.las
# ETA:  0:02:07
# Rt._20130818(171)_LAS1_2.las
# ETA:  0:02:06
# Rt._20130818(172)_LAS1_2.las
# ETA:  0:02:04
# Rt._20130818(173)_LAS1_2.las
# ETA:  0:02:02
# Rt._20130818(174)_LAS1_2.las
# ETA:  0:02:00
# Rt._20130818(175)_LAS1_2.las
# ETA:  0:01:58
# Rt._20130818(176)_LAS1_2.las
# ETA:  0:01:57
# Rt._20130818(177)_LAS1_2.las
# ETA:  0:01:55
# Rt._20130818(178)_LAS1_2.las
# ETA:  0:01:53
# Rt._20130818(179)_LAS1_2.las
# ETA:  0:01:51
# Rt._20130818(180)_LAS1_2.las
# ETA:  0:01:49
# Rt._20130818(181)_LAS1_2.las
# ETA:  0:01:48
# Rt._20130818(182)_LAS1_2.las
# ETA:  0:01:46
# Rt._20130818(183)_LAS1_2.las
# ETA:  0:01:44
# Rt._20130818(184)_LAS1_2.las
# ETA:  0:01:42
# Rt._20130818(185)_LAS1_2.las
# ETA:  0:01:41
# Rt._20130818(186)_LAS1_2.las
# ETA:  0:01:39
# Rt._20130818(187)_LAS1_2.las
# ETA:  0:01:37
# Rt._20130818(188)_LAS1_2.las
# ETA:  0:01:36
# Rt._20130818(189)_LAS1_2.las
# ETA:  0:01:34
# Rt._20130818(190)_LAS1_2.las
# ETA:  0:01:32
# Rt._20130818(191)_LAS1_2.las
# ETA:  0:01:31
# Rt._20130818(192)_LAS1_2.las
# ETA:  0:01:29
# Rt._20130818(193)_LAS1_2.las
# ETA:  0:01:27
# Rt._20130818(194)_LAS1_2.las
# ETA:  0:01:26
# Rt._20130818(195)_LAS1_2.las
# ETA:  0:01:24
# Rt._20130818(196)_LAS1_2.las
# ETA:  0:01:22
# Rt._20130818(197)_LAS1_2.las
# ETA:  0:01:21
# Rt._20130818(198)_LAS1_2.las
# ETA:  0:01:19
# Rt._20130818(199)_LAS1_2.las
# ETA:  0:01:18
# Rt._20130818(200)_LAS1_2.las
# ETA:  0:01:16
# Rt._20130818(201)_LAS1_2.las
# ETA:  0:01:14
# Rt._20130818(202)_LAS1_2.las
# ETA:  0:01:13
# Rt._20130818(203)_LAS1_2.las
# ETA:  0:01:11
# Rt._20130818(204)_LAS1_2.las
# ETA:  0:01:10
# Rt._20130818(205)_LAS1_2.las
# ETA:  0:01:08
# Rt._20130818(206)_LAS1_2.las
# ETA:  0:01:06
# Rt._20130818(207)_LAS1_2.las
# ETA:  0:01:05
# Rt._20130818(208)_LAS1_2.las
# ETA:  0:01:03
# Rt._20130818(209)_LAS1_2.las
# ETA:  0:01:02
# Rt._20130818(210)_LAS1_2.las
# ETA:  0:01:00
# Rt._20130818(211)_LAS1_2.las
# ETA:  0:00:59
# Rt._20130818(212)_LAS1_2.las
# ETA:  0:00:57
# Rt._20130818(213)_LAS1_2.las
# ETA:  0:00:56
# Rt._20130818(214)_LAS1_2.las
# ETA:  0:00:54
# Rt._20130818(215)_LAS1_2.las
# ETA:  0:00:53
# Rt._20130818(216)_LAS1_2.las
# ETA:  0:00:51
# Rt._20130818(217)_LAS1_2.las
# ETA:  0:00:50
# Rt._20130818(218)_LAS1_2.las
# ETA:  0:00:48
# Rt._20130818(219)_LAS1_2.las
# ETA:  0:00:47
# Rt._20130818(220)_LAS1_2.las
# ETA:  0:00:45
# Rt._20130818(221)_LAS1_2.las
# ETA:  0:00:44
# Rt._20130818(222)_LAS1_2.las
# ETA:  0:00:42
# Rt._20130818(223)_LAS1_2.las
# ETA:  0:00:41
# Rt._20130818(224)_LAS1_2.las
# ETA:  0:00:39
# Rt._20130818(225)_LAS1_2.las
# ETA:  0:00:38
# Rt._20130818(226)_LAS1_2.las
# ETA:  0:00:36
# Rt._20130818(227)_LAS1_2.las
# ETA:  0:00:35
# Rt._20130818(228)_LAS1_2.las
# ETA:  0:00:33
# Rt._20130818(229)_LAS1_2.las
# ETA:  0:00:32
# Rt._20130818(230)_LAS1_2.las
# ETA:  0:00:31
# Rt._20130818(231)_LAS1_2.las
# ETA:  0:00:29
# Rt._20130818(232)_LAS1_2.las
# ETA:  0:00:28
# Rt._20130818(233)_LAS1_2.las
# ETA:  0:00:26
# Rt._20130818(234)_LAS1_2.las
# ETA:  0:00:25
# Rt._20130818(235)_LAS1_2.las
# ETA:  0:00:24
# Rt._20130818(236)_LAS1_2.las
# ETA:  0:00:22
# Rt._20130818(237)_LAS1_2.las
# ETA:  0:00:21
# Rt._20130818(238)_LAS1_2.las
# ETA:  0:00:19
# Rt._20130818(239)_LAS1_2.las
# ETA:  0:00:18
# Rt._20130818(240)_LAS1_2.las
# ETA:  0:00:17
# Rt._20130818(241)_LAS1_2.las
# ETA:  0:00:15
# Rt._20130818(242)_LAS1_2.las
# ETA:  0:00:14
# Rt._20130818(243)_LAS1_2.las
# ETA:  0:00:13
# Rt._20130818(246)_LAS1_2.las
# ETA:  0:00:11
# Rt._20130818(247)_LAS1_2.las
# ETA:  0:00:10
# Rt._20130818(248)_LAS1_2.las
# ETA:  0:00:09
# Rt._20130818(249)_LAS1_2.las
# ETA:  0:00:07
# Rt._20130818(250)_LAS1_2.las
# ETA:  0:00:06
# Rt._20130818(251)_LAS1_2.las
# ETA:  0:00:05
# Rt._20130818(252)_LAS1_2.las
# ETA:  0:00:03
# Rt._20130818(253)_LAS1_2.las
# ETA:  0:00:02
# Rt._20130818(256)_LAS1_2.las
# ETA:  0:00:01
# Rt._20130818(257)_LAS1_2.las

# %%
from skimage.filter import gaussian_filter
sr = ras[:,:,:3].astype(float)/0xFFFF
mask = ras[:,:,3] == 0xFFFFFFFF 
sr[mask] = 0.5

# %%
sigma=0.5
    
for i in range(50):
    sr[mask,:] = gaussian_filter(sr, sigma)[mask,:]

figure()
imshow(sr)
figure()
imshow(ras[:,:,:3].astype(float)/0xFFFF)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-383-54d586abdf3e> in <module>()
#       2
#       3 for i in range(50):
# ----> 4     sr[mask,:] = gaussian_filter(sr, sigma)[mask,:]
#       5
#       6 figure()
#
# C:\Anaconda\envs\srp\lib\site-packages\skimage\filters\_gaussian.pyc in gaussian_filter(image, sigma, output, mode, cval, multichannel)
#     101             sigma = np.concatenate((np.asarray(sigma), [0]))
#     102     image = img_as_float(image)
# --> 103     return ndimage.gaussian_filter(image, sigma, mode=mode, cval=cval)
#
# C:\Anaconda\envs\srp\lib\site-packages\scipy\ndimage\filters.pyc in gaussian_filter(input, sigma, order, output, mode, cval, truncate)
#     303         for axis, sigma, order in axes:
#     304             gaussian_filter1d(input, sigma, axis, order, output,
# --> 305                               mode, cval, truncate)
#     306             input = output
#     307     else:
#
# C:\Anaconda\envs\srp\lib\site-packages\scipy\ndimage\filters.pyc in gaussian_filter1d(input, sigma, axis, order, output, mode, cval, truncate)
#     246             weights[lw + ii] = -tmp
#     247             weights[lw - ii] = tmp
# --> 248     return correlate1d(input, weights, axis, output, mode, cval, 0)
#     249
#     250
#
# C:\Anaconda\envs\srp\lib\site-packages\scipy\ndimage\filters.pyc in correlate1d(input, weights, axis, output, mode, cval, origin)
#     142     mode = _ni_support._extend_mode_to_code(mode)
#     143     _nd_image.correlate1d(input, weights, axis, output, mode, cval,
# --> 144                           origin)
#     145     return return_value
#     146
#
# KeyboardInterrupt:

# %%
x, y = 3000, 3000
imshow(sr[x-200:x+200, y-200:y+200])

# %%
G = opening(ras[:,:,3], disk(10))
imshow(sobel_h(G))

# %% [markdown]
# In order to avoid using too many parameters, I keep the raster image parameters in a dictionary called profile

# %% [raw]
# profile = {}
# profile.update(driver='GTiff', compress='lzw')
#
# profile.update(width=width,  height=height)
#
# # We are doing  r,g,b,z
# profile.update(count=4)
#
# # Use proj4 since GDAL / rasterio has a ahard time with EPSG codes (on windows/conda)
# profile.update(crs=proj4_2223)
#
#
# # Place the image within the CRS
# profile.update(transform=rasterio.transform.from_bounds(xmin, ymin, xmax, ymax, width, height))
#
# #  65,535 inches is just over one mile (this is height). Plenty of resolution/
# profile.update(dtype=rasterio.uint32, nodata=0)

# %% [raw]
# with rasterio.open('rgbz0_inches3.tif', mode='w', **profile) as ds:
#     ds.write(ras[:,:,0].T.astype(np.uint32), 1)
#     ds.write(ras[:,:,1].T.astype(np.uint32), 2)
#     ds.write(ras[:,:,2].T.astype(np.uint32), 3)
#     ds.write(ras[:,:,3].T.astype(np.uint32), 4)

# %% [markdown]
# If the raster was already generated, we can just load it from disk.

# %%
with rasterio.open('rgbz0_inches3.tif', mode='r') as ds:
    affine = ds.affine
    ras = ds.read().transpose(2,1,0)
print ras.shape
# Out:
# (11036L, 11023L, 4L)

# %%
sample_site = (693127.4977482168, 899945.426647059) # (692156.90,902044.55)
row, col = ~ds.affine*sample_site
row, col = int(round(row)), int(round(col))
figsize(20,10)
gray()
sub = ras[row-100:row+100, col-100:col+100].copy()
alpha = sub[:,:,3] < 0xFFFFFFFF
vmin, vmax = np.percentile(sub[:,:,3][alpha], (10, 98))
print vmin,  vmax

subplot(1,2,1)
imshow(sub[:,:,3], vmin=vmin, vmax=vmax)
title('Z')

subplot(1,2,2)
vmin, vmax = np.percentile(sub[:,:,:3][alpha], (0, 100))
imshow((sub[:,:,:3]-vmin)/(vmax-vmin));
# Out:
# 15415.6315632 15459.0347466

# %%
average_cabinet_width = 1.0 #meters
cabinet_width_in_inches = average_cabinet_width * meters_to_inches
cabinet_width_in_pixels = cabinet_width_in_inches / 6  #6 inches per pixel
max_cabinet_width = int(1.5 * cabinet_width_in_pixels)
print 'average_cabinet_width', average_cabinet_width
print 'cabinet_width_in_inches', cabinet_width_in_inches
print 'cabinet_width_in_pixels', cabinet_width_in_pixels
print 'max_cabinet_width', max_cabinet_width
# Out:
# average_cabinet_width 1.0
# cabinet_width_in_inches 39.3701
# cabinet_width_in_pixels 6.56168333333
# max_cabinet_width 9

# %%
from skimage.morphology import opening, disk
structuring_element = disk(max_cabinet_width//2 + 1)
Z = ras[:,:, 3]
Zground = opening(Z, selem=structuring_element)

# %%
from skimage.filter import sobel_h

# %%
epsg2223.transform_point( -111.939205, 33.473875, epsg2223.as_geodetic())
# Out:
# (693127.4977482168, 899945.426647059)

# %%
def visualize(lat, lon, radius=50):
    row, col = ~ds.affine*(lat, lon)
    row, col = int(round(row)), int(round(col))
    figsize(20,20)
    gray()
    subZground = Zground[row-radius:row+radius, col-radius:col+radius].copy()
    subZ = Z[row-radius:row+radius, col-radius:col+radius].copy()
    alpha = subZ[:,:] < 0xFFFFFFFF
    subRGB = ras[row-radius:row+radius, col-radius:col+radius,:3].copy().astype(float)
    subRGB /= subRGB[alpha].max()

    subplot(2,2,1)
    imshow(sobel_h(subZground, alpha))
    title('ground Z (edges)')

    subplot(2,2,2)
    imshow(sobel_h(subZ, alpha))
    title('min Z of LiDAR scan (edges)')
    
    subplot(2,2,3)
    imshow(subRGB)
    grid()
    
    subplot(2,2,4)
    dz = (subZ-subZground).astype(float)

    imshow(dz/12.0, vmin=0, vmax=1)
    grid()
    #colorbar()


#visualize(692156.90,902044.55-500, radius=200)
visualize(693127.4977482168, 899945.426647059, radius=100)

# %%
diff = Z - Zground
diff[Z == 0xFFFFFFFF] = 0

# %%
subDiff = diff[row-100:row+100, col-100:col+100]
imshow(subDiff/12., vmax=6)  # Up to six feet in height
colorbar();

# %%
from skimage.measure import label
from skimage.segmentation import mark_boundaries
from skimage.morphology import opening, disk, closing

# %%
tmp = opening(closing(subDiff, disk(1)), disk(1))
#imshow(mark_boundaries(tmp/(10*12.0), label(tmp > 12) ))
imshow(tmp/12.0, vmax=7)

# %%
imshow(alpha)

# %%
from skimage.measure import regionprops
import pandas as pd
labels = label(tmp>24)
regions = regionprops(labels, subDiff)

# %%
data = numpy.zeros((len(regions), 4))
for i, r in enumerate(regions):
    data[i] = r.min_intensity, r.max_intensity, r.area, r.perimeter

# %%
df = pd.DataFrame(data, columns=['min z', 'max z', 'area', 'perimeter'])
df
# Out:
#     min z  max z  area   perimeter
# 0       0     94     7    7.656854
# 1      22     31    54   33.798990
# 2       0    116    47   22.763456
# 3       0      4     5    5.656854
# 4       0     93   449  174.350288
# 5      40    153    20   15.899495
# 6       0     97    33   20.970563
# 7       0     95    72   36.455844
# 8       1     83    13   10.485281
# 9       0     93    21   14.727922
# 10      0     93   160   70.669048
# 11      6     75    48   29.798990
# 12     29     32     8    7.656854
# 13      7     48    13   11.313708
# 14     46     50    42   21.899495

# %%
scatter(df['min z'], df['max z']-df['min z'])
grid()
xlim(0, 7*12)
ylim(0, 2*12)
yticks(arange(0, 2*12));xticks(arange(0, 7*12, 3));

# %%
hist(df['area'], bins=20);
display(df)
# Out:
#     min z  max z  area   perimeter
# 0       0     94     7    7.656854
# 1      22     31    54   33.798990
# 2       0    116    47   22.763456
# 3       0      4     5    5.656854
# 4       0     93   449  174.350288
# 5      40    153    20   15.899495
# 6       0     97    33   20.970563
# 7       0     95    72   36.455844
# 8       1     83    13   10.485281
# 9       0     93    21   14.727922
# 10      0     93   160   70.669048
# 11      6     75    48   29.798990
# 12     29     32     8    7.656854
# 13      7     48    13   11.313708
# 14     46     50    42   21.899495

# %%
df["max z"]/12
# Out:
# 0      7.833333
# 1      2.583333
# 2      9.666667
# 3      0.333333
# 4      7.750000
# 5     12.750000
# 6      8.083333
# 7      7.916667
# 8      6.916667
# 9      7.750000
# 10     7.750000
# 11     6.250000
# 12     2.666667
# 13     4.000000
# 14     4.166667
# Name: max z, dtype: float64

# %%
imshow(sum([(labels == x) for x in (13+1, 14+1, 12+1,)], axis=0));

# %%
figsize(8,8)
imshow(tmp == 1);
print tmp.dtype
# Out:
# uint32

# %%
mean_height = 4*12  #Ball park guess
stdev_height = 12 # +/1 one foot?
imshow(exp( -(subDiff-mean_height)**2/(stdev_height**2)  ))
colorbar()

# %%
imshow(abs(subDiff-mean_height) <= stdev_height)  # 68% rule --> majority of box points within this range

# %%
from skimage.morphology import binary_opening, binary_closing

# %%
def binary_seive(a, minsize, maxsize):
    return binary_opening(a, disk(minsize)) &~ binary_opening(a, disk(maxsize))

# %%
sub_box_tops = abs(subDiff-mean_height) <= stdev_height   
# 68% probability threshold  -- according to my made up mean +stdev....
sub_box_tops = binary_seive(sub_box_tops, cabinet_width_in_pixels//4 + 1,  cabinet_width_in_pixels)
imshow(sub_box_tops);

# %%
prbs = exp(-(diff - mean_height)**2/(stdev_height**2))

# %%
box_tops = abs(diff - mean_height) < stdev_height
imshow(box_tops)

# %%
box_tops = binary_seive(box_tops, cabinet_width_in_pixels//4 + 1,  cabinet_width_in_pixels)
imshow(box_tops);

# %%
from skimage.measure import regionprops, label

# %%
labeled_box_tops = label(box_tops)

# %%
props = regionprops(labeled_box_tops, diff)

# %%
len(props)
index = randint(0, len(props))
region = props[index]

# %%
region.centroid
# Out:
# (4534.0, 3519.0)

# %%
from skimage.segmentation import mark_boundaries

# %%
row, col = region.centroid
rad = 50
row, col = int(row), int(col)
#imshow(ras[row-rad:row+rad, col-rad:col+rad, :3]/0xFFFF)
# imshow(mark_boundaries( (255*ras[row-rad:row+rad, col-rad:col+rad, :3]/0xFFFF).astype(np.uint8), 
#                        box_tops[row-rad:row+rad, col-rad:col+rad].astype(int)))

# imshow(mark_boundaries( diff[row-rad:row+rad, col-rad:col+rad]/diff[row-rad:row+rad, col-rad:col+rad].max(), 
#                        box_tops[row-rad:row+rad, col-rad:col+rad].astype(int)))

imshow(mark_boundaries( prbs[row-rad:row+rad, col-rad:col+rad]/prbs[row-rad:row+rad, col-rad:col+rad].max(), 
                       box_tops[row-rad:row+rad, col-rad:col+rad].astype(int)))

# %%
gx, gy = ds.affine*(row, col)
print gx, gy
lat, lon = epsg2223.as_geodetic().transform_point(gx, gy, epsg2223)
print  round(lon, 6), ',', round(lat, 6)
# Out:
# 693945.008061 900532.356579
# 33.475489 , -111.936524

# %% [raw]
# figsize(15, 15)
# rad=50
# #tiler = cartopy.io.img_tiles.GoogleTiles(style='satellite')
# tiler = cartopy.io.img_tiles.OSM()
# epsg2223 = cartopy.crs.epsg(2223) # State Plane AZ Central (ft)
# ax = plt.axes(projection=tiler.crs)
# ax.add_image(tiler, 21)
# ax.scatter(gx, gy,
#            s=0.1,
#            zorder=5,
#            transform=epsg2223.as_geodetic())
# ax.set_extent((gx-rad, gx+rad, gy-rad, gy+rad), crs=epsg2223)
#
# show()

# %%
import fiona

# %%
schema = {}
schema['geometry'] = 'Point'
schema['properties'] = [('height', 'float')]
crs=pyepsg.get(2223).as_proj4()

# %%
recs =[]
for r in props:
    x, y = ds.affine*r.centroid
    rec = {}
    rec['geometry'] = {'type':'Point', 'coordinates':(x, y)}
    rec['properties'] = {'height': r.max_intensity}
    recs.append(rec)

# %%
ep = pyepsg.get(2223).base_geodetic_crs.as_proj4()
# Out:
# u'+proj=longlat +ellps=GRS80 +towgs84=0,0,0,0,0,0,0 +no_defs '

# %%
with fiona.open('boxes1', 'w', driver="ESRI Shapefile", crs=crs, schema=schema) as s:
    s.writerecords(recs)

# %%
trail = zip(list(rawdata['x']), list(rawdata['y']))
trail_record = {
    'geometry': {'type':'LineString', 'coordinates':trail},
    'properties': {}
}
trail_schema = {'geometry':'LineString', 'properties':[]}
trail_crs = pyepsg.get(2223).base_geodetic_crs.as_proj4()
with fiona.open('trail', 'w', driver="ESRI Shapefile", crs=trail_crs, schema=trail_schema) as s:
    s.writerecords([trail_record])

# %%
0xFFFFFFFF
# Out:
# 4294967295L

# %%
profile = {}
profile.update(driver='GTiff', compress='lzw')
ft_per_pixel = 6.0/12.0  # 6 inches (0.5 ft)\
width=int(ceil((xmax-xmin)/ft_per_pixel))
height=int(ceil((ymax-ymin)/ft_per_pixel))
profile.update(width=width,  height=height)
profile.update(count=1)
profile.update(crs=proj4_2223)
profile.update(transform=rasterio.transform.from_bounds(xmin, ymin, xmax, ymax, width, height))
profile.update(dtype=rasterio.float32, nodata=0xFFFFFFFF)
with rasterio.open('probs.tif', mode='w', **profile) as ds:
    ds.write(prbs[:,:].T.astype(np.float32), 1)

# %%
profile = {}
profile.update(driver='GTiff', compress='lzw')
ft_per_pixel = 6.0/12.0  # 6 inches (0.5 ft)\
width=int(ceil((xmax-xmin)/ft_per_pixel))
height=int(ceil((ymax-ymin)/ft_per_pixel))
profile.update(width=width,  height=height)
profile.update(count=1)
profile.update(crs=proj4_2223)
profile.update(transform=rasterio.transform.from_bounds(xmin, ymin, xmax, ymax, width, height))
profile.update(dtype=rasterio.float32, nodata=0xFFFFFFFF)
with rasterio.open('ground.tif', mode='w', **profile) as ds:
    ds.write(Zground[:,:].T.astype(np.float32), 1)

# %%
import time
poverall = FloatProgress(min=0, max=len(files))
display(poverall)
p = FloatProgress(min=0, max=1)
display(p)
workdone = 0

print "Allocating..."
maxras = np.zeros((height, width, 4), dtype=np.uint32)
sources = np.zeros((height, width), dtype=np.uint16)
print "Allocated...."

tstart = time.clock()

for file_index, basefn in enumerate(files):
    
    # Progress display so I know how long I have to get coffee
    poverall.value = file_index
    p.value = 0
    
    seconds = ((time.clock()-tstart)/max(file_index,1))*(len(files)-file_index)
    minutes, seconds = divmod(seconds, 60)
    hours, minutes = divmod(minutes, 60)
    print "ETA:  %d:%02d:%02d" % (hours,  minutes, seconds)
    
    print basefn
    fn = os.path.join(folder, basefn)
    f = laspy.file.File(fn)
    x = f.x
    y = f.y
    z = f.z
    r = f.red
    g = f.green
    b = f.blue
    xyzf = epsg2223.transform_points(epsg26949, x, y, z)
    xyzf[:, 2] *= 12 #inches
    rc = np.column_stack(~affine*xyzf[:,:2].T).astype(int)

    print "\rSorting",
    indices = np.argsort(xyzf[:, 2] )
    valid_indices = ((rc[indices, 1] < width) 
                     & (rc[indices, 1] > 0) 
                     & (rc[indices, 0] < height)
                     & (rc[indices, 0] > 0))
    indices = indices[valid_indices]

    tmp = np.zeros_like(maxras)
    chunksize  = 1000
    n = len(indices)
    print '\r', n,
    p.max = n
    for start in range(0, n, chunksize):
        end = min(start + chunksize, n)
        ix = indices[start:end]
        tmp[rc[ix, 0], rc[ix, 1], 0] = r[ix]
        tmp[rc[ix, 0], rc[ix, 1], 1] = g[ix]
        tmp[rc[ix, 0], rc[ix, 1], 2] = b[ix]
        tmp[rc[ix, 0], rc[ix, 1], 3] = xyzf[ix, 2]
        p.value = start
        print '\r{:>10} / {}'.format(end, n), 
    
    updates = tmp[:,:,3] > maxras[:,:,3]
    maxras[updates] = tmp[updates]
    sources[updates] = file_index
    
    xmin_, ymin_ = rc.min(0)
    xmax_, ymax_ = rc.max(0)
    clear_output()
    
    # Save images for debugging
    im = maxras[xmin_:xmax_, ymin_:ymax_, 3].copy()
    vmean = xyzf[:,2].mean()
    vdev = xyzf[:,2].std()
    vmin = vmean - vdev
    vmax = vmean + vdev
    try:
        if not os.path.isdir('tmp'):
            os.makedirs('tmp')
        imsave('tmp/'+ basefn +'.tif', im, cmap=cm.gray, vmin=vmin, vmax=vmax);
        imshow(im, cmap=cm.gray, vmin=vmin, vmax=vmax);
        show()
    except:
        print "Image was probably too small to save / show. This is an apparent bug in the imsave function."
    display()
# Out:
#  Image was probably too small to save / show. This is an apparent bug in the imsave function.
